# %%
import sys
sys.path.append('../')

# %%
from bootstrapping.bootstrapping import BootStrapping
from utility.file_utility import FileUtility

# %%
files=FileUtility.recursive_glob('/mounts/data/proj/asgari/github_repos/microbiomephenotype/data_config/bodysites/','*.txt')
list_of_files=[]
for file in files:
    list_of_files+=FileUtility.load_list(file)
list_of_files=[x+'.fsa' for x in list_of_files]
fasta_files, mapping = FileUtility.read_fasta_directory('/mounts/data/proj/asgari/dissertation/datasets/deepbio/microbiome/hmb_data/','fsa',only_files=list_of_files)
BS=BootStrapping(fasta_files,'body', seqtype='fsa', N_files=10)

# %%
BS.add_npe_sampling('../../datasets/processed_data/body-site/cpe/cpe_16s_5000','NPE 5000')
# Out:
#  sampling size  10  is started ...
#  sampling size  10  is completed.
#  sampling size  20  is started ...
#  sampling size  20  is completed.
#  sampling size  50  is started ...
#  sampling size  50  is completed.
#  sampling size  100  is started ...
#  sampling size  100  is completed.
#  sampling size  200  is started ...
#  sampling size  200  is completed.
#  sampling size  500  is started ...
#  sampling size  500  is completed.
#  sampling size  1000  is started ...
#  sampling size  1000  is completed.
#  sampling size  2000  is started ...
#  sampling size  2000  is completed.
#  sampling size  5000  is started ...
#  sampling size  5000  is completed.
#  sampling size  10000  is started ...
#  sampling size  10000  is completed.

# %%
BS.add_npe_sampling('../../datasets/processed_data/body-site/cpe/cpe_16s_15000','NPE 15000')
# Out:
#  sampling size  10  is started ...
#  sampling size  10  is completed.
#  sampling size  20  is started ...
#  sampling size  20  is completed.
#  sampling size  50  is started ...
#  sampling size  50  is completed.
#  sampling size  100  is started ...
#  sampling size  100  is completed.
#  sampling size  200  is started ...
#  sampling size  200  is completed.
#  sampling size  500  is started ...
#  sampling size  500  is completed.
#  sampling size  1000  is started ...
#  sampling size  1000  is completed.
#  sampling size  2000  is started ...
#  sampling size  2000  is completed.
#  sampling size  5000  is started ...
#  sampling size  5000  is completed.
#  sampling size  10000  is started ...
#  sampling size  10000  is completed.

# %%
BS.add_npe_sampling('../../datasets/processed_data/body-site/cpe/cpe_16s_10000','NPE 10000')
# Out:
#  sampling size  10  is started ...
#  sampling size  10  is completed.
#  sampling size  20  is started ...
#  sampling size  20  is completed.
#  sampling size  50  is started ...
#  sampling size  50  is completed.
#  sampling size  100  is started ...
#  sampling size  100  is completed.
#  sampling size  200  is started ...
#  sampling size  200  is completed.
#  sampling size  500  is started ...
#  sampling size  500  is completed.
#  sampling size  1000  is started ...
#  sampling size  1000  is completed.
#  sampling size  2000  is started ...
#  sampling size  2000  is completed.
#  sampling size  5000  is started ...
#  sampling size  5000  is completed.
#  sampling size  10000  is started ...
#  sampling size  10000  is completed.

# %%
BS.add_npe_sampling('../../datasets/processed_data/body-site/cpe/cpe_16s_1000','NPE 1000')
# Out:
#  sampling size  10  is started ...
#  sampling size  10  is completed.
#  sampling size  20  is started ...
#  sampling size  20  is completed.
#  sampling size  50  is started ...
#  sampling size  50  is completed.
#  sampling size  100  is started ...
#  sampling size  100  is completed.
#  sampling size  200  is started ...
#  sampling size  200  is completed.
#  sampling size  500  is started ...
#  sampling size  500  is completed.
#  sampling size  1000  is started ...
#  sampling size  1000  is completed.
#  sampling size  2000  is started ...
#  sampling size  2000  is completed.
#  sampling size  5000  is started ...
#  sampling size  5000  is completed.
#  sampling size  10000  is started ...
#  sampling size  10000  is completed.

# %%
BS.add_npe_sampling('../../datasets/processed_data/body-site/cpe/cpe_16s_2000','NPE 2000')
# Out:
#  sampling size  10  is started ...
#  sampling size  10  is completed.
#  sampling size  20  is started ...
#  sampling size  20  is completed.
#  sampling size  50  is started ...
#  sampling size  50  is completed.
#  sampling size  100  is started ...
#  sampling size  100  is completed.
#  sampling size  200  is started ...
#  sampling size  200  is completed.
#  sampling size  500  is started ...
#  sampling size  500  is completed.
#  sampling size  1000  is started ...
#  sampling size  1000  is completed.
#  sampling size  2000  is started ...
#  sampling size  2000  is completed.
#  sampling size  5000  is started ...
#  sampling size  5000  is completed.
#  sampling size  10000  is started ...
#  sampling size  10000  is completed.

# %%
for k in [3,4,5,6,7,8]:
    print(k)
    BS.add_kmer_sampling(k)

# %%
BS=FileUtility.load_obj('../../../../github_repos/microbiomephenotype/results/dental/prev_files/bootrapping.pickle.pickle')

# %%
class New(object):
    def __init__(self):
        print ('created')
self=New()
[self.x, self.y, self.error,self.y_tot,self.error_tot]=FileUtility.load_obj('../../datasets/results/crohn/bootstrapping/crohn_bootstrap_npe.pickle')
# Out:
# created

# %%
import matplotlib.pyplot as plt
# %pylab inline
# %matplotlib inline 

#self=BS
figure(figsize=(20, 10))
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
matplotlib.pyplot.title(r'ABC123 vs $\mathrm{ABC123}^{123}$')
matplotlib.rcParams['mathtext.fontset'] = 'custom'
matplotlib.rcParams['mathtext.rm'] = 'Bitstream Vera Sans'
matplotlib.rcParams['mathtext.it'] = 'Bitstream Vera Sans:italic'
matplotlib.rcParams['mathtext.bf'] = 'Bitstream Vera Sans:bold'
matplotlib.pyplot.title(r'ABC123 vs $\mathrm{ABC123}^{123}$')
plt.rc('text', usetex=True)
ax=subplot(121)
k_mers=['NPE 1000','NPE 2000','NPE 5000','NPE 10000','NPE 15000']

legend_vals=[]
for k in k_mers:
    ax.plot(self.x[k], np.array(self.y[k]))
    ax.fill_between(self.x[k], np.array(self.y[k])-np.array(self.error[k]),np.array(self.y[k])+np.array(self.error[k]),alpha=0.2, linewidth=4, linestyle='dashdot', antialiased=True)
    legend_vals.append(str(k))
ax.legend(legend_vals, loc='upper right', prop={'size': 30},ncol=1)
xlabel('Resample size (N)', fontsize=24)
ylabel(r'$\bar{D_S}(N,\#NPE)$', fontsize=24)
xlim([0,10000])
ylim([0,180])
title(r'(i) \textbf{Self-inconsistency $\bar{D_S}$,} with respect to resample size (N)\\ demonstrated for different NPE vocabulary sizes in the Crohn dataset', fontsize=24,y=1.01)

ax=subplot(122)

k_mers=['NPE 1000','NPE 2000','NPE 5000','NPE 10000','NPE 15000']
legend_vals=[]
for k in k_mers:
    ax.plot(self.x[k], np.array(self.y_tot[k]))
    ax.fill_between(self.x[k], np.array(self.y_tot[k])-np.array(self.error_tot[k]), np.array(self.y_tot[k])+np.array(self.error_tot[k]),alpha=0.2, linewidth=4, linestyle='dashdot', antialiased=True)
    legend_vals.append(str(k))
ax.legend(legend_vals, loc='upper right', prop={'size': 30},ncol=1)
xlim([0,10000])
ylim([0,1.8])
plt.rc('text', usetex=True)
xlabel('Resample size (N)', fontsize=24)
ylabel(r'$\bar{D_R}(N,\#NPE)$', fontsize=24)
title(r'(ii) \textbf{Unrepresentativeness $\bar{D_R}$,} with respect to resample size (N)\\ demonstrated for different NPE vocabulary sizes in the Crohn dataset', fontsize=24, y=1.01)
plt.tight_layout()
plt.savefig('../../datasets/figures/paper_figures/crohn-disease_bootstrapp_NPE.pdf')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fasta_files, mapping = FileUtility.read_fasta_directory('/mounts/data/proj/asgari/dissertation/datasets/deepbio/microbiome/crohn/','fastq')
BS=BootStrapping(fasta_files,'crohn', seqtype='fastq', N_files=10)

# %%
BS.add_npe_sampling('../../datasets/processed_data/crohn/npe/cpe_16s_5000','NPE 5000')
# Out:
#  sampling size  10  is started ...
#  sampling size  10  is completed.
#  sampling size  20  is started ...
#  sampling size  20  is completed.
#  sampling size  50  is started ...
#  sampling size  50  is completed.
#  sampling size  100  is started ...
#  sampling size  100  is completed.
#  sampling size  200  is started ...
#  sampling size  200  is completed.
#  sampling size  500  is started ...
#  sampling size  500  is completed.
#  sampling size  1000  is started ...
#  sampling size  1000  is completed.
#  sampling size  2000  is started ...
#  sampling size  2000  is completed.
#  sampling size  5000  is started ...
#  sampling size  5000  is completed.
#  sampling size  10000  is started ...
#  sampling size  10000  is completed.

# %%
BS.add_npe_sampling('../../datasets/processed_data/crohn/npe/cpe_16s_15000','NPE 15000')
# Out:
#  sampling size  10  is started ...
#  sampling size  10  is completed.
#  sampling size  20  is started ...
#  sampling size  20  is completed.
#  sampling size  50  is started ...
#  sampling size  50  is completed.
#  sampling size  100  is started ...
#  sampling size  100  is completed.
#  sampling size  200  is started ...
#  sampling size  200  is completed.
#  sampling size  500  is started ...
#  sampling size  500  is completed.
#  sampling size  1000  is started ...
#  sampling size  1000  is completed.
#  sampling size  2000  is started ...
#  sampling size  2000  is completed.
#  sampling size  5000  is started ...
#  sampling size  5000  is completed.
#  sampling size  10000  is started ...
#  sampling size  10000  is completed.

# %%
BS.add_npe_sampling('../../datasets/processed_data/crohn/npe/cpe_16s_10000','NPE 10000')
# Out:
#  sampling size  10  is started ...
#  sampling size  10  is completed.
#  sampling size  20  is started ...
#  sampling size  20  is completed.
#  sampling size  50  is started ...
#  sampling size  50  is completed.
#  sampling size  100  is started ...
#  sampling size  100  is completed.
#  sampling size  200  is started ...
#  sampling size  200  is completed.
#  sampling size  500  is started ...
#  sampling size  500  is completed.
#  sampling size  1000  is started ...
#  sampling size  1000  is completed.
#  sampling size  2000  is started ...
#  sampling size  2000  is completed.
#  sampling size  5000  is started ...
#  sampling size  5000  is completed.
#  sampling size  10000  is started ...
#  sampling size  10000  is completed.

# %%
BS.add_npe_sampling('../../datasets/processed_data/crohn/npe/cpe_16s_2000','NPE 2000')
# Out:
#  sampling size  10  is started ...
#  sampling size  10  is completed.
#  sampling size  20  is started ...
#  sampling size  20  is completed.
#  sampling size  50  is started ...
#  sampling size  50  is completed.
#  sampling size  100  is started ...
#  sampling size  100  is completed.
#  sampling size  200  is started ...
#  sampling size  200  is completed.
#  sampling size  500  is started ...
#  sampling size  500  is completed.
#  sampling size  1000  is started ...
#  sampling size  1000  is completed.
#  sampling size  2000  is started ...
#  sampling size  2000  is completed.
#  sampling size  5000  is started ...
#  sampling size  5000  is completed.
#  sampling size  10000  is started ...
#  sampling size  10000  is completed.

# %%
BS.add_npe_sampling('../../datasets/processed_data/crohn/npe/cpe_16s_1000','NPE 1000')
# Out:
#  sampling size  10  is started ...
#  sampling size  10  is completed.
#  sampling size  20  is started ...
#  sampling size  20  is completed.
#  sampling size  50  is started ...
#  sampling size  50  is completed.
#  sampling size  100  is started ...
#  sampling size  100  is completed.
#  sampling size  200  is started ...
#  sampling size  200  is completed.
#  sampling size  500  is started ...
#  sampling size  500  is completed.
#  sampling size  1000  is started ...
#  sampling size  1000  is completed.
#  sampling size  2000  is started ...
#  sampling size  2000  is completed.
#  sampling size  5000  is started ...
#  sampling size  5000  is completed.
#  sampling size  10000  is started ...
#  sampling size  10000  is completed.

# %%
self2=BS
FileUtility.save_obj('../../datasets/results/crohn/bootstrapping/crohn_bootstrap_npe',[self2.x, self2.y, self2.error,self2.y_tot,self2.error_tot])
