# %%
import sys
sys.path.append('../')
import matplotlib.pyplot as plt
# %pylab inline
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from utility.file_utility import FileUtility

# %%
from utility.visualization_utility import create_mat_plot

# %% [markdown]
# # Bodysite

# %%
[label_set, conf, best_score_, best_estimator_,cv_results_, best_params_]=FileUtility.load_obj('/mounts/data/proj/asgari/dissertation/git_repos/MicroPheno/results/classification_results/bodysite/sampling_rate/6-mers_rate_5000_labels_labels_phen.txt_RF.pickle')
create_mat_plot(conf, ['saliva (o)', 'mid-vagina (u)','a-nares (n)', 'stool (g)', 'p-fornix (u)'], '', '/mounts/data/proj/asgari/dissertation/git_repos/MicroPheno/results/paper_figures/bodysite_confusion', 'Predicted labels' ,'Actual labels', cmap='Purples', filetype='pdf')

# %% [markdown]
# # Organism

# %%
[label_set, conf, best_score_, best_estimator_,cv_results_, best_params_]=FileUtility.load_obj('/mounts/data/proj/asgari/dissertation/git_repos/MicroPheno/results/classification_results/env/6_org_RF.pickle')

# %%
label_set=[x.replace('_',' ') for x in label_set]

# %%
create_mat_plot(conf, label_set, '', '/mounts/data/proj/asgari/dissertation/git_repos/MicroPheno/results/paper_figures/org_env_confusion', 'Predicted labels' ,'Actual labels', cmap='Purples', filetype='pdf')

# %% [markdown]
# # Ecological

# %%
[label_set, conf, best_score_, best_estimator_,cv_results_, best_params_]=FileUtility.load_obj('/mounts/data/proj/asgari/dissertation/git_repos/MicroPheno/results/classification_results/env/6_eco_RF_RF.pickle')

# %%
label_set=[x.replace('_',' ') for x in label_set]

# %%
create_mat_plot(conf, label_set, '', '/mounts/data/proj/asgari/dissertation/git_repos/MicroPheno/results/paper_figures/eco_env_confusion', 'Predicted labels' ,'Actual labels', cmap='Purples', filetype='pdf', rx=80, ry=0, font_s=7)
