# %%
import sys
sys.path.append('../')
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from utility.file_utility import FileUtility
from utility.visualization_utility import plot_scatter
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %pylab inline
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def plot_pca_tsne_nn(X_pca, X_tsne, X_tsne_NN, Y, filename=False,  legend_size=7, label_dic=False, color_idx=2, loc=[(4,1),(4,1),(4,1)]):
    myplot=figure(figsize=(24, 8))
    ax=subplot(131)
    plot_scatter(ax, X_pca, Y, 'PCA_1', 'PCA_0', '(i) PCA over 6-mer representations', loc[0][0], legend_col=loc[0][1], legend_size=legend_size, label_dict=label_dic, color_schemes_idx=color_idx)
    ax=subplot(132)
    plot_scatter(ax, X_tsne, Y, 't-SNE_1', 't-SNE_0', '(ii) t-SNE over 6-mer representations', loc[1][0], legend_col=loc[1][1],  legend_size=legend_size,label_dict=label_dic, color_schemes_idx=color_idx)
    ax=subplot(133)
    plot_scatter(ax, X_tsne_NN, Y, 't-SNE_1', 't-SNE_0', '(iii) t-SNE / activation function of the last layer of neural network', loc[2][0], legend_col=loc[2][1],  legend_size=legend_size, label_dict=label_dic, color_schemes_idx=color_idx)
    myplot.tight_layout()
    if filename:
        plt.savefig(filename+'.pdf')
    else:
        plt.show()

# %%
def get_pca_tsne(X, X_NN):    
    X_pca = PCA(n_components=50).fit_transform(X.toarray())
    X_tsne = TSNE(n_components=2, perplexity=40, verbose=2, learning_rate=10).fit_transform(X.toarray())
    X_tsne_NN = TSNE(n_components=2, perplexity=40, verbose=2, learning_rate=10).fit_transform(X_NN)
    return X_pca, X_tsne, X_tsne_NN

# %%
def create_tsne_web(X, Y, tsne_file_coor, tsne_file_label):
    classes=list(set(Y))
    classes.sort()
    L=[classes.index(y) for y in Y]
    tsne_res = np.hstack((X, np.array([L]).T))
    tsne_res[:,0:2]=np.round(tsne_res[:,0:2],2)
    tsne_lines=[]
    for l in tsne_res:
        tsne_lines.append('\t'.join([str(l[0]), str(l[1]), str(int(l[2]))]))
    FileUtility.save_list(tsne_file_coor,tsne_lines)
    FileUtility.save_list(tsne_file_label,Y)

# %% [markdown]
# # Body-site

# %%
X=FileUtility.load_sparse_csr('../../datasets/processed_data/body-site/K/6-mers_rate_2000.npz')
X_NN=np.loadtxt('../../datasets/processed_data/body-site/visualization/Activation_3layers')
Y=FileUtility.load_list('../../datasets/processed_data/body-site/data_config/labels_phen.txt')
label_dict={'saliva':'saliva (oral)','vagina':'mid vagina (urogenital)','nose':'anterior nares (nasal)','stool':'stool (gut)','posterior':'posterior fornix (urogenital)'}

# %%
X_pca_bs, X_tsne_bs, X_tsne_NN_bs=get_pca_tsne(X, X_NN)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 1192 samples in 0.096s...
# [t-SNE] Computed neighbors for 1192 samples in 8.516s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1192
# [t-SNE] Computed conditional probabilities for sample 1192 / 1192
# [t-SNE] Mean sigma: 0.005435
# [t-SNE] Computed conditional probabilities in 0.096s
# [t-SNE] Iteration 50: error = 68.4876862, gradient norm = 0.0068887 (50 iterations in 0.855s)
# [t-SNE] Iteration 100: error = 52.1957817, gradient norm = 0.0071015 (50 iterations in 0.987s)
# [t-SNE] Iteration 150: error = 50.4098587, gradient norm = 0.0028498 (50 iterations in 0.809s)
# [t-SNE] Iteration 200: error = 49.8661423, gradient norm = 0.0018148 (50 iterations in 0.815s)
# [t-SNE] Iteration 250: error = 49.6036148, gradient norm = 0.0013866 (50 iterations in 0.798s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 49.603615
# [t-SNE] Iteration 300: error = 1.0518130, gradient norm = 0.0048042 (50 iterations in 0.807s)
# [t-SNE] Iteration 350: error = 0.7618856, gradient norm = 0.0020168 (50 iterations in 0.832s)
# [t-SNE] Iteration 400: error = 0.6307631, gradient norm = 0.0011385 (50 iterations in 0.833s)
# [t-SNE] Iteration 450: error = 0.5611612, gradient norm = 0.0007290 (50 iterations in 0.992s)
# [t-SNE] Iteration 500: error = 0.5196671, gradient norm = 0.0005101 (50 iterations in 1.008s)
# [t-SNE] Iteration 550: error = 0.4924415, gradient norm = 0.0003903 (50 iterations in 0.853s)
# [t-SNE] Iteration 600: error = 0.4731563, gradient norm = 0.0003135 (50 iterations in 0.840s)
# [t-SNE] Iteration 650: error = 0.4592752, gradient norm = 0.0002610 (50 iterations in 0.845s)
# [t-SNE] Iteration 700: error = 0.4490454, gradient norm = 0.0002285 (50 iterations in 0.825s)
# [t-SNE] Iteration 750: error = 0.4414243, gradient norm = 0.0001978 (50 iterations in 0.828s)
# [t-SNE] Iteration 800: error = 0.4357921, gradient norm = 0.0001825 (50 iterations in 0.827s)
# [t-SNE] Iteration 850: error = 0.4314926, gradient norm = 0.0001738 (50 iterations in 0.849s)
# [t-SNE] Iteration 900: error = 0.4285011, gradient norm = 0.0001696 (50 iterations in 0.839s)
# [t-SNE] Iteration 950: error = 0.4256390, gradient norm = 0.0001603 (50 iterations in 0.826s)
# [t-SNE] Iteration 1000: error = 0.4239627, gradient norm = 0.0001565 (50 iterations in 0.836s)
# [t-SNE] Error after 1000 iterations: 0.423963
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 1192 samples in 0.001s...
# [t-SNE] Computed neighbors for 1192 samples in 0.028s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1192
# [t-SNE] Computed conditional probabilities for sample 1192 / 1192
# [t-SNE] Mean sigma: 0.264210
# [t-SNE] Computed conditional probabilities in 0.059s
# [t-SNE] Iteration 50: error = 69.4041595, gradient norm = 0.0058148 (50 iterations in 0.827s)
# [t-SNE] Iteration 100: error = 52.7060089, gradient norm = 0.0074747 (50 iterations in 0.802s)
# [t-SNE] Iteration 150: error = 50.9364319, gradient norm = 0.0036495 (50 iterations in 0.764s)
# [t-SNE] Iteration 200: error = 50.3438454, gradient norm = 0.0025308 (50 iterations in 0.761s)
# [t-SNE] Iteration 250: error = 50.0300026, gradient norm = 0.0019961 (50 iterations in 0.756s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 50.030003
# [t-SNE] Iteration 300: error = 1.0071396, gradient norm = 0.0055252 (50 iterations in 0.764s)
# [t-SNE] Iteration 350: error = 0.6876677, gradient norm = 0.0022342 (50 iterations in 0.824s)
# [t-SNE] Iteration 400: error = 0.5427219, gradient norm = 0.0012292 (50 iterations in 0.819s)
# [t-SNE] Iteration 450: error = 0.4642813, gradient norm = 0.0007912 (50 iterations in 0.820s)
# [t-SNE] Iteration 500: error = 0.4171700, gradient norm = 0.0005611 (50 iterations in 0.826s)
# [t-SNE] Iteration 550: error = 0.3867233, gradient norm = 0.0004200 (50 iterations in 0.830s)
# [t-SNE] Iteration 600: error = 0.3660575, gradient norm = 0.0003302 (50 iterations in 0.817s)
# [t-SNE] Iteration 650: error = 0.3517200, gradient norm = 0.0002700 (50 iterations in 0.805s)
# [t-SNE] Iteration 700: error = 0.3409688, gradient norm = 0.0002332 (50 iterations in 0.801s)
# [t-SNE] Iteration 750: error = 0.3324787, gradient norm = 0.0002120 (50 iterations in 0.816s)
# [t-SNE] Iteration 800: error = 0.3264065, gradient norm = 0.0001971 (50 iterations in 0.806s)
# [t-SNE] Iteration 850: error = 0.3215075, gradient norm = 0.0001762 (50 iterations in 0.800s)
# [t-SNE] Iteration 900: error = 0.3173899, gradient norm = 0.0001668 (50 iterations in 0.802s)
# [t-SNE] Iteration 950: error = 0.3140500, gradient norm = 0.0001604 (50 iterations in 0.807s)
# [t-SNE] Iteration 1000: error = 0.3112686, gradient norm = 0.0001508 (50 iterations in 0.800s)
# [t-SNE] Error after 1000 iterations: 0.311269

# %%
plot_pca_tsne_nn(X_pca_bs, X_tsne_bs, X_tsne_NN_bs, Y, filename=False, legend_size=6, label_dic=label_dict, color_idx=0, loc=[4,3,2])

# %% [markdown]
# # Ecological Environment

# %%
global color_schemes
color_schemes=[['green','blue','red','gold', 'cyan'], ['#ff0505', '#f2a041', '#cdff05', '#04d9cb', '#45a8ff', '#8503a6', '#590202', '#734d02', '#4ab304', '#025359', '#0454cc', '#ff45da', '#993829', '#ffda45', '#1c661c', '#05cdff', '#1c2f66', '#731f57', '#b24a04', '#778003', '#0e3322', '#024566', '#0404d9', '#e5057d', '#66391c', '#31330e', '#3ee697', '#2d7da6', '#20024d', '#33011c']+list(({'aliceblue':            '#F0F8FF','antiquewhite':         '#FAEBD7','aqua':                 '#00FFFF','aquamarine':           '#7FFFD4','azure':                '#F0FFFF','beige':                '#F5F5DC','bisque':               '#FFE4C4','black':                '#000000','blanchedalmond':       '#FFEBCD','blue':                 '#0000FF','blueviolet':           '#8A2BE2','brown':                '#A52A2A','burlywood':            '#DEB887','cadetblue':            '#5F9EA0','chartreuse':           '#7FFF00','chocolate':            '#D2691E','coral':                '#FF7F50','cornflowerblue':       '#6495ED','cornsilk':             '#FFF8DC','crimson':              '#DC143C','cyan':                 '#00FFFF','darkblue':             '#00008B','darkcyan':             '#008B8B','darkgoldenrod':        '#B8860B','darkgray':             '#A9A9A9','darkgreen':            '#006400','darkkhaki':            '#BDB76B','darkmagenta':          '#8B008B','darkolivegreen':       '#556B2F','darkorange':           '#FF8C00','darkorchid':           '#9932CC','darkred':              '#8B0000','darksalmon':           '#E9967A','darkseagreen':         '#8FBC8F','darkslateblue':        '#483D8B','darkslategray':        '#2F4F4F','darkturquoise':        '#00CED1','darkviolet':           '#9400D3','deeppink':             '#FF1493','deepskyblue':          '#00BFFF','dimgray':              '#696969','dodgerblue':           '#1E90FF','firebrick':            '#B22222','floralwhite':          '#FFFAF0','forestgreen':          '#228B22','fuchsia':              '#FF00FF','gainsboro':            '#DCDCDC','ghostwhite':           '#F8F8FF','gold':                 '#FFD700','goldenrod':            '#DAA520','gray':                 '#808080','green':                '#008000','greenyellow':          '#ADFF2F','honeydew':             '#F0FFF0','hotpink':              '#FF69B4','indianred':            '#CD5C5C','indigo':               '#4B0082','ivory':                '#FFFFF0','khaki':                '#F0E68C','lavender':             '#E6E6FA','lavenderblush':        '#FFF0F5','lawngreen':            '#7CFC00','lemonchiffon':         '#FFFACD','lightblue':            '#ADD8E6','lightcoral':           '#F08080','lightcyan':            '#E0FFFF','lightgoldenrodyellow': '#FAFAD2','lightgreen':           '#90EE90','lightgray':            '#D3D3D3','lightpink':            '#FFB6C1','lightsalmon':          '#FFA07A','lightseagreen':        '#20B2AA','lightskyblue':         '#87CEFA','lightslategray':       '#778899','lightsteelblue':       '#B0C4DE','lightyellow':          '#FFFFE0','lime':                 '#00FF00','limegreen':            '#32CD32','linen':                '#FAF0E6','magenta':              '#FF00FF','maroon':               '#800000','mediumaquamarine':     '#66CDAA','mediumblue':           '#0000CD','mediumorchid':         '#BA55D3','mediumpurple':         '#9370DB','mediumseagreen':       '#3CB371','mediumslateblue':      '#7B68EE','mediumspringgreen':    '#00FA9A','mediumturquoise':      '#48D1CC','mediumvioletred':      '#C71585','midnightblue':         '#191970','mintcream':            '#F5FFFA','mistyrose':            '#FFE4E1','moccasin':             '#FFE4B5','navajowhite':          '#FFDEAD','navy':                 '#000080','oldlace':              '#FDF5E6','olive':                '#808000','olivedrab':            '#6B8E23','orange':               '#FFA500','orangered':            '#FF4500','orchid':               '#DA70D6','palegoldenrod':        '#EEE8AA','palegreen':            '#98FB98','paleturquoise':        '#AFEEEE','palevioletred':        '#DB7093','papayawhip':           '#FFEFD5','peachpuff':            '#FFDAB9','peru':                 '#CD853F','pink':                 '#FFC0CB','plum':                 '#DDA0DD','powderblue':           '#B0E0E6','purple':               '#800080','red':                  '#FF0000','rosybrown':            '#BC8F8F','royalblue':            '#4169E1','saddlebrown':          '#8B4513','salmon':               '#FA8072','sandybrown':           '#FAA460','seagreen':             '#2E8B57','seashell':             '#FFF5EE','sienna':               '#A0522D','silver':               '#C0C0C0','skyblue':              '#87CEEB','slateblue':            '#6A5ACD','slategray':            '#708090','snow':                 '#FFFAFA','springgreen':          '#00FF7F','steelblue':            '#4682B4','tan':                  '#D2B48C','teal':                 '#008080','thistle':              '#D8BFD8','tomato':               '#FF6347','turquoise':            '#40E0D0','violet':               '#EE82EE','wheat':                '#F5DEB3','white':                '#FFFFFF','whitesmoke':           '#F5F5F5','yellow':               '#FFFF00','yellowgreen':          '#9ACD32'}).keys()),['#ff0505', '#f2a041', '#cdff05', '#04d9cb', '#45a8ff', '#8503a6', '#590202', '#734d02', '#4ab304', '#025359', '#0454cc', '#ff45da', '#993829', '#ffda45', '#1c661c', '#05cdff', '#1c2f66', '#731f57', '#b24a04', '#778003', '#0e3322', '#024566', '#0404d9', '#e5057d', '#66391c', '#31330e', '#3ee697', '#2d7da6', '#20024d', '#33011c']]

# %%
def plot_scatter(ax, X, Y, x_label, y_label, title,legend_hide=True, legend_loc=4, label_dict=False, legend_size=7, legend_col=1, color_schemes_idx=1):
    
    global color_schemes
    
    target=list(set(Y))
    target.sort()
    color_idx=[target.index(x) for x in Y]
    color_list=color_schemes[color_schemes_idx]
  
    for current_color in range(len(target)):
        color=color_list
        current_idxs=[idx for idx,v in enumerate(color_idx) if v==current_color]
        if label_dict:
            ax.scatter(X[current_idxs, 0], X[current_idxs, 1], c=color[current_color], label=label_dict[target[current_color]], cmap='viridis', alpha=0.4, edgecolors=None)
        else:
            ax.scatter(X[current_idxs, 0], X[current_idxs, 1], c=color[current_color], label=target[current_color], cmap='viridis', alpha=0.4, edgecolors=None)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.xticks([])
    plt.yticks([])
    ax.set_title(title)
    if not legend_hide:
        ax.legend(loc=legend_loc, bbox_to_anchor=(0.5, -0.1), prop={'size': legend_size},ncol=legend_col, edgecolor='black', facecolor='white', frameon=True)
    matplotlib.rcParams['mathtext.fontset'] = 'stix'
    matplotlib.rcParams['font.family'] = 'STIXGeneral'
    matplotlib.rcParams['mathtext.fontset'] = 'custom'
    matplotlib.rcParams['mathtext.rm'] = 'Bitstream Vera Sans'
    matplotlib.rcParams['mathtext.it'] = 'Bitstream Vera Sans:italic'
    matplotlib.rcParams['mathtext.bf'] = 'Bitstream Vera Sans:bold'
    matplotlib.rcParams["axes.edgecolor"] = "black"
    matplotlib.rcParams["axes.linewidth"] = 0.6
    plt.rc('text', usetex=True)
    rect = ax.patch
    rect.set_facecolor('white')

# %%
from classifier.DNN import DNNMutliclass16S

X=FileUtility.load_sparse_csr('../../datasets/processed_data/eco_10000/K/6-mer_eco_restrictedmer.npz')
#X_NN=np.loadtxt('../../datasets/results/eco_10000/classifiers/')
X_NN=DNNMutliclass16S.make_activation_function('../../datasets/results/eco_10000/classifiers/nn_layers_mlp_1024-0.2-1024-0.2-512-0.2-512-0.1-64-1024_0.86.pickle', X.toarray())

# %%
Y=FileUtility.load_list('../../datasets/processed_data/eco_10000/K/eco_label_restrictedkmer.txt')
label_dict=None

# %%
X_NN.shape
# Out:
# (180000, 1024)

# %%
#rand_idx=np.random.choice(180000, 3600, replace=False)
#FileUtility.save_list('../../datasets/processed_data/eco/visualization/rand_idx_10000.txt',[str(x) for x in list(rand_idx)])
rand_idx=[int(x) for x in FileUtility.load_list('../../datasets/processed_data/eco/visualization/rand_idx_10000.txt')]

# %%
len(rand_idx)
# Out:
# 3600

# %%
Y=[Y[idx] for idx in list(rand_idx)]
X=X[rand_idx,:]
X_NN=X_NN[rand_idx,:]

# %%
X_pca_ec, X_tsne_ec, X_tsne_NN_ec=get_pca_tsne(X, X_NN)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 3600 samples in 0.718s...
# [t-SNE] Computed neighbors for 3600 samples in 74.337s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3600
# [t-SNE] Computed conditional probabilities for sample 2000 / 3600
# [t-SNE] Computed conditional probabilities for sample 3000 / 3600
# [t-SNE] Computed conditional probabilities for sample 3600 / 3600
# [t-SNE] Mean sigma: 0.015322
# [t-SNE] Computed conditional probabilities in 0.279s
# [t-SNE] Iteration 50: error = 78.8815460, gradient norm = 0.0000678 (50 iterations in 3.756s)
# [t-SNE] Iteration 100: error = 77.4170837, gradient norm = 0.0127420 (50 iterations in 3.708s)
# [t-SNE] Iteration 150: error = 68.7619781, gradient norm = 0.0015391 (50 iterations in 3.659s)
# [t-SNE] Iteration 200: error = 68.0302277, gradient norm = 0.0004570 (50 iterations in 3.678s)
# [t-SNE] Iteration 250: error = 67.9477081, gradient norm = 0.0001291 (50 iterations in 3.704s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 67.947708
# [t-SNE] Iteration 300: error = 2.6385887, gradient norm = 0.0054227 (50 iterations in 3.766s)
# [t-SNE] Iteration 350: error = 2.1745923, gradient norm = 0.0025508 (50 iterations in 3.727s)
# [t-SNE] Iteration 400: error = 1.9483023, gradient norm = 0.0015562 (50 iterations in 3.671s)
# [t-SNE] Iteration 450: error = 1.8078504, gradient norm = 0.0010715 (50 iterations in 3.629s)
# [t-SNE] Iteration 500: error = 1.7121999, gradient norm = 0.0008083 (50 iterations in 3.620s)
# [t-SNE] Iteration 550: error = 1.6418736, gradient norm = 0.0006349 (50 iterations in 3.650s)
# [t-SNE] Iteration 600: error = 1.5877774, gradient norm = 0.0005225 (50 iterations in 3.626s)
# [t-SNE] Iteration 650: error = 1.5447975, gradient norm = 0.0004387 (50 iterations in 3.642s)
# [t-SNE] Iteration 700: error = 1.5094628, gradient norm = 0.0003768 (50 iterations in 3.643s)
# [t-SNE] Iteration 750: error = 1.4805549, gradient norm = 0.0003261 (50 iterations in 3.638s)
# [t-SNE] Iteration 800: error = 1.4561198, gradient norm = 0.0002861 (50 iterations in 3.646s)
# [t-SNE] Iteration 850: error = 1.4351182, gradient norm = 0.0002532 (50 iterations in 3.640s)
# [t-SNE] Iteration 900: error = 1.4169164, gradient norm = 0.0002258 (50 iterations in 3.632s)
# [t-SNE] Iteration 950: error = 1.4009892, gradient norm = 0.0002033 (50 iterations in 3.636s)
# [t-SNE] Iteration 1000: error = 1.3869984, gradient norm = 0.0001849 (50 iterations in 3.642s)
# [t-SNE] Error after 1000 iterations: 1.386998
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 3600 samples in 0.098s...
# [t-SNE] Computed neighbors for 3600 samples in 5.263s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3600
# [t-SNE] Computed conditional probabilities for sample 2000 / 3600
# [t-SNE] Computed conditional probabilities for sample 3000 / 3600
# [t-SNE] Computed conditional probabilities for sample 3600 / 3600
# [t-SNE] Mean sigma: 3.050766
# [t-SNE] Computed conditional probabilities in 0.183s
# [t-SNE] Iteration 50: error = 82.8196030, gradient norm = 0.0000182 (50 iterations in 2.994s)
# [t-SNE] Iteration 100: error = 72.7451401, gradient norm = 0.0098241 (50 iterations in 2.886s)
# [t-SNE] Iteration 150: error = 61.4436913, gradient norm = 0.0035506 (50 iterations in 2.755s)
# [t-SNE] Iteration 200: error = 58.4935837, gradient norm = 0.0019887 (50 iterations in 2.783s)
# [t-SNE] Iteration 250: error = 57.2412872, gradient norm = 0.0013663 (50 iterations in 2.787s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 57.241287
# [t-SNE] Iteration 300: error = 1.9433028, gradient norm = 0.0042738 (50 iterations in 2.810s)
# [t-SNE] Iteration 350: error = 1.5302608, gradient norm = 0.0026577 (50 iterations in 2.868s)
# [t-SNE] Iteration 400: error = 1.2425594, gradient norm = 0.0017374 (50 iterations in 2.862s)
# [t-SNE] Iteration 450: error = 1.0544484, gradient norm = 0.0012271 (50 iterations in 2.878s)
# [t-SNE] Iteration 500: error = 0.9263564, gradient norm = 0.0009149 (50 iterations in 2.875s)
# [t-SNE] Iteration 550: error = 0.8351696, gradient norm = 0.0007116 (50 iterations in 2.865s)
# [t-SNE] Iteration 600: error = 0.7677089, gradient norm = 0.0005730 (50 iterations in 2.868s)
# [t-SNE] Iteration 650: error = 0.7158878, gradient norm = 0.0004729 (50 iterations in 2.858s)
# [t-SNE] Iteration 700: error = 0.6748275, gradient norm = 0.0004015 (50 iterations in 2.906s)
# [t-SNE] Iteration 750: error = 0.6419293, gradient norm = 0.0003410 (50 iterations in 3.004s)
# [t-SNE] Iteration 800: error = 0.6152658, gradient norm = 0.0002956 (50 iterations in 2.909s)
# [t-SNE] Iteration 850: error = 0.5929771, gradient norm = 0.0002597 (50 iterations in 2.904s)
# [t-SNE] Iteration 900: error = 0.5742426, gradient norm = 0.0002291 (50 iterations in 2.925s)
# [t-SNE] Iteration 950: error = 0.5580863, gradient norm = 0.0002104 (50 iterations in 2.918s)
# [t-SNE] Iteration 1000: error = 0.5441011, gradient norm = 0.0001904 (50 iterations in 2.918s)
# [t-SNE] Error after 1000 iterations: 0.544101

# %%
def plot_pca_tsne_nn(X_pca, X_tsne, X_tsne_NN, Y, filename=False,  legend_size=7, label_dic=False, color_idx=2, loc=[(4,1),(4,1),(4,1)]):
    myplot=figure(figsize=(12, 12))
    ax=subplot(221)
    plot_scatter(ax, X_pca, Y, 'PCA_1', 'PCA_0', '(i) PCA over 6-mer representations',legend_hide=True, legend_loc=loc[0][0], legend_col=loc[0][1], legend_size=legend_size, label_dict=label_dic, color_schemes_idx=color_idx)
    ax=subplot(222)
    plot_scatter(ax, X_tsne, Y, 't-SNE_1', 't-SNE_0', '(ii) t-SNE over 6-mer representations',legend_hide=False,  legend_loc=9, legend_col=loc[1][1],  legend_size=legend_size,label_dict=label_dic, color_schemes_idx=color_idx)
    ax=subplot(223)
    plot_scatter(ax, X_tsne_NN, Y, 't-SNE_1', 't-SNE_0', '(iii) t-SNE / activation function of the last layer of neural network',legend_hide=True,  legend_loc=loc[2][0], legend_col=loc[2][1],  legend_size=legend_size, label_dict=label_dic, color_schemes_idx=color_idx)
    myplot.tight_layout()
    if filename:
        plt.savefig(filename+'.pdf')
    else:
        plt.show()

# %%
plot_pca_tsne_nn(X_pca_ec, X_tsne_ec, X_tsne_NN_ec, [x.replace('_',' ') for x in Y], filename='../../datasets/figures/paper_figures/temp.pdf', legend_size=16, label_dic=False, color_idx=2, loc=[(1,2),(1,2),(1,2)])

# %%
X=FileUtility.load_sparse_csr('../../datasets/processed_data/eco_all_classes/6-mer_eco_restrictedmer_all.npz')
X_NN=np.loadtxt('../../datasets/results/eco_all/activation_from_pretrained_0.88.txt')
Y=FileUtility.load_list('../../datasets/processed_data/eco_all_classes/eco_label_restrictedkmer_all.txt')
label_dict=None

# %%
rand_idx=np.random.choice(X.shape[0], 3600, replace=False)

# %%
FileUtility.save_list('../../datasets/processed_data/eco_all_classes/rand_idx.txt',[str(x) for x in list(rand_idx)])
Y=[Y[idx] for idx in list(rand_idx)]
X=X[rand_idx,:]
X_NN=X_NN[rand_idx,:]

# %%
X_pca_ec, X_tsne_ec, X_tsne_NN_ec=get_pca_tsne(X, X_NN)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 3600 samples in 0.729s...
# [t-SNE] Computed neighbors for 3600 samples in 74.143s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3600
# [t-SNE] Computed conditional probabilities for sample 2000 / 3600
# [t-SNE] Computed conditional probabilities for sample 3000 / 3600
# [t-SNE] Computed conditional probabilities for sample 3600 / 3600
# [t-SNE] Mean sigma: 0.015452
# [t-SNE] Computed conditional probabilities in 0.297s
# [t-SNE] Iteration 50: error = 79.1179352, gradient norm = 0.0000738 (50 iterations in 3.639s)
# [t-SNE] Iteration 100: error = 78.9146042, gradient norm = 0.0045446 (50 iterations in 3.479s)
# [t-SNE] Iteration 150: error = 72.4213486, gradient norm = 0.0013967 (50 iterations in 3.343s)
# [t-SNE] Iteration 200: error = 71.8802338, gradient norm = 0.0003617 (50 iterations in 3.443s)
# [t-SNE] Iteration 250: error = 71.8586349, gradient norm = 0.0001199 (50 iterations in 3.457s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.858635
# [t-SNE] Iteration 300: error = 2.7647812, gradient norm = 0.0058481 (50 iterations in 3.535s)
# [t-SNE] Iteration 350: error = 2.2406387, gradient norm = 0.0025892 (50 iterations in 3.481s)
# [t-SNE] Iteration 400: error = 2.0000644, gradient norm = 0.0015581 (50 iterations in 3.416s)
# [t-SNE] Iteration 450: error = 1.8543738, gradient norm = 0.0010829 (50 iterations in 3.393s)
# [t-SNE] Iteration 500: error = 1.7554590, gradient norm = 0.0008056 (50 iterations in 3.386s)
# [t-SNE] Iteration 550: error = 1.6837025, gradient norm = 0.0006383 (50 iterations in 3.395s)
# [t-SNE] Iteration 600: error = 1.6289145, gradient norm = 0.0005199 (50 iterations in 3.404s)
# [t-SNE] Iteration 650: error = 1.5853105, gradient norm = 0.0004365 (50 iterations in 3.404s)
# [t-SNE] Iteration 700: error = 1.5501976, gradient norm = 0.0003749 (50 iterations in 3.406s)
# [t-SNE] Iteration 750: error = 1.5210201, gradient norm = 0.0003295 (50 iterations in 3.408s)
# [t-SNE] Iteration 800: error = 1.4963166, gradient norm = 0.0002889 (50 iterations in 3.412s)
# [t-SNE] Iteration 850: error = 1.4754456, gradient norm = 0.0002550 (50 iterations in 3.416s)
# [t-SNE] Iteration 900: error = 1.4574580, gradient norm = 0.0002284 (50 iterations in 3.412s)
# [t-SNE] Iteration 950: error = 1.4417747, gradient norm = 0.0002066 (50 iterations in 3.416s)
# [t-SNE] Iteration 1000: error = 1.4279461, gradient norm = 0.0001892 (50 iterations in 3.419s)
# [t-SNE] Error after 1000 iterations: 1.427946
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 3600 samples in 0.044s...
# [t-SNE] Computed neighbors for 3600 samples in 8.338s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3600
# [t-SNE] Computed conditional probabilities for sample 2000 / 3600
# [t-SNE] Computed conditional probabilities for sample 3000 / 3600
# [t-SNE] Computed conditional probabilities for sample 3600 / 3600
# [t-SNE] Mean sigma: 1.851714
# [t-SNE] Computed conditional probabilities in 0.177s
# [t-SNE] Iteration 50: error = 81.9593506, gradient norm = 0.0000022 (50 iterations in 3.080s)
# [t-SNE] Iteration 100: error = 81.6008301, gradient norm = 0.0032317 (50 iterations in 4.310s)
# [t-SNE] Iteration 150: error = 76.3234024, gradient norm = 0.0007047 (50 iterations in 3.207s)
# [t-SNE] Iteration 200: error = 76.1362228, gradient norm = 0.0001606 (50 iterations in 3.021s)
# [t-SNE] Iteration 250: error = 76.1235733, gradient norm = 0.0000886 (50 iterations in 2.985s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 76.123573
# [t-SNE] Iteration 300: error = 2.8198810, gradient norm = 0.0057668 (50 iterations in 2.945s)
# [t-SNE] Iteration 350: error = 2.2378387, gradient norm = 0.0026699 (50 iterations in 2.880s)
# [t-SNE] Iteration 400: error = 1.9677088, gradient norm = 0.0015921 (50 iterations in 2.894s)
# [t-SNE] Iteration 450: error = 1.8126740, gradient norm = 0.0010803 (50 iterations in 2.888s)
# [t-SNE] Iteration 500: error = 1.7124140, gradient norm = 0.0007936 (50 iterations in 2.883s)
# [t-SNE] Iteration 550: error = 1.6424539, gradient norm = 0.0006157 (50 iterations in 2.875s)
# [t-SNE] Iteration 600: error = 1.5909081, gradient norm = 0.0004960 (50 iterations in 2.879s)
# [t-SNE] Iteration 650: error = 1.5512329, gradient norm = 0.0004072 (50 iterations in 2.884s)
# [t-SNE] Iteration 700: error = 1.5201231, gradient norm = 0.0003421 (50 iterations in 2.878s)
# [t-SNE] Iteration 750: error = 1.4949318, gradient norm = 0.0002962 (50 iterations in 2.880s)
# [t-SNE] Iteration 800: error = 1.4743022, gradient norm = 0.0002626 (50 iterations in 2.877s)
# [t-SNE] Iteration 850: error = 1.4570615, gradient norm = 0.0002257 (50 iterations in 2.876s)
# [t-SNE] Iteration 900: error = 1.4425603, gradient norm = 0.0002026 (50 iterations in 2.878s)
# [t-SNE] Iteration 950: error = 1.4303763, gradient norm = 0.0001843 (50 iterations in 2.879s)
# [t-SNE] Iteration 1000: error = 1.4201655, gradient norm = 0.0001638 (50 iterations in 2.883s)
# [t-SNE] Error after 1000 iterations: 1.420166

# %%
global color_schemes
color_schemes=[['green','blue','red','gold', 'cyan'], ['#ff0505', '#f2a041', '#cdff05', '#04d9cb', '#45a8ff', '#8503a6', '#590202', '#734d02', '#4ab304', '#025359', '#0454cc', '#ff45da', '#993829', '#ffda45', '#1c661c', '#05cdff', '#1c2f66', '#731f57', '#b24a04', '#778003', '#0e3322', '#024566', '#0404d9', '#e5057d', '#66391c', '#31330e', '#3ee697', '#2d7da6', '#20024d', '#33011c']+list(({'aliceblue':            '#F0F8FF','antiquewhite':         '#FAEBD7','aqua':                 '#00FFFF','aquamarine':           '#7FFFD4','azure':                '#F0FFFF','beige':                '#F5F5DC','bisque':               '#FFE4C4','black':                '#000000','blanchedalmond':       '#FFEBCD','blue':                 '#0000FF','blueviolet':           '#8A2BE2','brown':                '#A52A2A','burlywood':            '#DEB887','cadetblue':            '#5F9EA0','chartreuse':           '#7FFF00','chocolate':            '#D2691E','coral':                '#FF7F50','cornflowerblue':       '#6495ED','cornsilk':             '#FFF8DC','crimson':              '#DC143C','cyan':                 '#00FFFF','darkblue':             '#00008B','darkcyan':             '#008B8B','darkgoldenrod':        '#B8860B','darkgray':             '#A9A9A9','darkgreen':            '#006400','darkkhaki':            '#BDB76B','darkmagenta':          '#8B008B','darkolivegreen':       '#556B2F','darkorange':           '#FF8C00','darkorchid':           '#9932CC','darkred':              '#8B0000','darksalmon':           '#E9967A','darkseagreen':         '#8FBC8F','darkslateblue':        '#483D8B','darkslategray':        '#2F4F4F','darkturquoise':        '#00CED1','darkviolet':           '#9400D3','deeppink':             '#FF1493','deepskyblue':          '#00BFFF','dimgray':              '#696969','dodgerblue':           '#1E90FF','firebrick':            '#B22222','floralwhite':          '#FFFAF0','forestgreen':          '#228B22','fuchsia':              '#FF00FF','gainsboro':            '#DCDCDC','ghostwhite':           '#F8F8FF','gold':                 '#FFD700','goldenrod':            '#DAA520','gray':                 '#808080','green':                '#008000','greenyellow':          '#ADFF2F','honeydew':             '#F0FFF0','hotpink':              '#FF69B4','indianred':            '#CD5C5C','indigo':               '#4B0082','ivory':                '#FFFFF0','khaki':                '#F0E68C','lavender':             '#E6E6FA','lavenderblush':        '#FFF0F5','lawngreen':            '#7CFC00','lemonchiffon':         '#FFFACD','lightblue':            '#ADD8E6','lightcoral':           '#F08080','lightcyan':            '#E0FFFF','lightgoldenrodyellow': '#FAFAD2','lightgreen':           '#90EE90','lightgray':            '#D3D3D3','lightpink':            '#FFB6C1','lightsalmon':          '#FFA07A','lightseagreen':        '#20B2AA','lightskyblue':         '#87CEFA','lightslategray':       '#778899','lightsteelblue':       '#B0C4DE','lightyellow':          '#FFFFE0','lime':                 '#00FF00','limegreen':            '#32CD32','linen':                '#FAF0E6','magenta':              '#FF00FF','maroon':               '#800000','mediumaquamarine':     '#66CDAA','mediumblue':           '#0000CD','mediumorchid':         '#BA55D3','mediumpurple':         '#9370DB','mediumseagreen':       '#3CB371','mediumslateblue':      '#7B68EE','mediumspringgreen':    '#00FA9A','mediumturquoise':      '#48D1CC','mediumvioletred':      '#C71585','midnightblue':         '#191970','mintcream':            '#F5FFFA','mistyrose':            '#FFE4E1','moccasin':             '#FFE4B5','navajowhite':          '#FFDEAD','navy':                 '#000080','oldlace':              '#FDF5E6','olive':                '#808000','olivedrab':            '#6B8E23','orange':               '#FFA500','orangered':            '#FF4500','orchid':               '#DA70D6','palegoldenrod':        '#EEE8AA','palegreen':            '#98FB98','paleturquoise':        '#AFEEEE','palevioletred':        '#DB7093','papayawhip':           '#FFEFD5','peachpuff':            '#FFDAB9','peru':                 '#CD853F','pink':                 '#FFC0CB','plum':                 '#DDA0DD','powderblue':           '#B0E0E6','purple':               '#800080','red':                  '#FF0000','rosybrown':            '#BC8F8F','royalblue':            '#4169E1','saddlebrown':          '#8B4513','salmon':               '#FA8072','sandybrown':           '#FAA460','seagreen':             '#2E8B57','seashell':             '#FFF5EE','sienna':               '#A0522D','silver':               '#C0C0C0','skyblue':              '#87CEEB','slateblue':            '#6A5ACD','slategray':            '#708090','snow':                 '#FFFAFA','springgreen':          '#00FF7F','steelblue':            '#4682B4','tan':                  '#D2B48C','teal':                 '#008080','thistle':              '#D8BFD8','tomato':               '#FF6347','turquoise':            '#40E0D0','violet':               '#EE82EE','wheat':                '#F5DEB3','white':                '#FFFFFF','whitesmoke':           '#F5F5F5','yellow':               '#FFFF00','yellowgreen':          '#9ACD32'}).keys()),['#ff0505', '#f2a041', '#cdff05', '#04d9cb', '#45a8ff', '#8503a6', '#590202', '#734d02', '#4ab304', '#025359', '#0454cc', '#ff45da', '#993829', '#ffda45', '#1c661c', '#05cdff', '#1c2f66', '#731f57', '#b24a04', '#778003', '#0e3322', '#024566', '#0404d9', '#e5057d', '#66391c', '#31330e', '#3ee697', '#2d7da6', '#20024d', '#33011c']]

# %%
plot_pca_tsne_nn(X_pca_ec, X_tsne_ec, X_tsne_NN_ec, [x.replace('_',' ') for x in Y], filename='../../datasets/figures/paper_figures/eco_visualization_full.pdf', legend_size=7, label_dic=False, color_idx=1, loc=[(1,2),(1,2),(1,2)])

# %%
create_tsne_web(X_tsne_NN_ec, Y, 'tsne_file', 'tnse_label')

# %% [markdown]
# # Organismal

# %%
X=FileUtility.load_sparse_csr('../../datasets/processed_data/org/K/6-mer_org_restrictedkmer.npz')
X_NN=np.loadtxt('../../datasets/processed_data/org/visualization/Activation_6layers_org')
Y=FileUtility.load_list('../../datasets/processed_data/org/K/org_label_restrictedkmer.txt')
label_dict=None

# %%
X_pca_ec, X_tsne_ec, X_tsne_NN_ec=get_pca_tsne(X, X_NN)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 3100 samples in 0.770s...
# [t-SNE] Computed neighbors for 3100 samples in 60.977s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3100
# [t-SNE] Computed conditional probabilities for sample 2000 / 3100
# [t-SNE] Computed conditional probabilities for sample 3000 / 3100
# [t-SNE] Computed conditional probabilities for sample 3100 / 3100
# [t-SNE] Mean sigma: 0.018659
# [t-SNE] Computed conditional probabilities in 0.563s
# [t-SNE] Iteration 50: error = 77.8525314, gradient norm = 0.0000719 (50 iterations in 2.996s)
# [t-SNE] Iteration 100: error = 76.7240067, gradient norm = 0.0113532 (50 iterations in 2.807s)
# [t-SNE] Iteration 150: error = 71.2182922, gradient norm = 0.0003706 (50 iterations in 2.608s)
# [t-SNE] Iteration 200: error = 71.0172958, gradient norm = 0.0002216 (50 iterations in 2.581s)
# [t-SNE] Iteration 250: error = 70.9648743, gradient norm = 0.0001116 (50 iterations in 2.680s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.964874
# [t-SNE] Iteration 300: error = 2.5557930, gradient norm = 0.0062956 (50 iterations in 2.726s)
# [t-SNE] Iteration 350: error = 1.9528769, gradient norm = 0.0026886 (50 iterations in 2.860s)
# [t-SNE] Iteration 400: error = 1.6875443, gradient norm = 0.0016129 (50 iterations in 2.909s)
# [t-SNE] Iteration 450: error = 1.5311993, gradient norm = 0.0011101 (50 iterations in 2.800s)
# [t-SNE] Iteration 500: error = 1.4270446, gradient norm = 0.0008235 (50 iterations in 2.784s)
# [t-SNE] Iteration 550: error = 1.3529865, gradient norm = 0.0006481 (50 iterations in 2.881s)
# [t-SNE] Iteration 600: error = 1.2971998, gradient norm = 0.0005253 (50 iterations in 2.805s)
# [t-SNE] Iteration 650: error = 1.2537740, gradient norm = 0.0004354 (50 iterations in 2.788s)
# [t-SNE] Iteration 700: error = 1.2191632, gradient norm = 0.0003698 (50 iterations in 2.850s)
# [t-SNE] Iteration 750: error = 1.1908551, gradient norm = 0.0003178 (50 iterations in 2.801s)
# [t-SNE] Iteration 800: error = 1.1675375, gradient norm = 0.0002770 (50 iterations in 2.793s)
# [t-SNE] Iteration 850: error = 1.1478717, gradient norm = 0.0002456 (50 iterations in 2.796s)
# [t-SNE] Iteration 900: error = 1.1310979, gradient norm = 0.0002184 (50 iterations in 2.795s)
# [t-SNE] Iteration 950: error = 1.1166320, gradient norm = 0.0001977 (50 iterations in 2.800s)
# [t-SNE] Iteration 1000: error = 1.1041363, gradient norm = 0.0001808 (50 iterations in 2.794s)
# [t-SNE] Error after 1000 iterations: 1.104136
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 3100 samples in 0.004s...
# [t-SNE] Computed neighbors for 3100 samples in 0.280s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3100
# [t-SNE] Computed conditional probabilities for sample 2000 / 3100
# [t-SNE] Computed conditional probabilities for sample 3000 / 3100
# [t-SNE] Computed conditional probabilities for sample 3100 / 3100
# [t-SNE] Mean sigma: 1.389204
# [t-SNE] Computed conditional probabilities in 0.144s
# [t-SNE] Iteration 50: error = 81.0397644, gradient norm = 0.0000124 (50 iterations in 2.367s)
# [t-SNE] Iteration 100: error = 71.9299469, gradient norm = 0.0094082 (50 iterations in 2.685s)
# [t-SNE] Iteration 150: error = 63.8586731, gradient norm = 0.0026880 (50 iterations in 2.334s)
# [t-SNE] Iteration 200: error = 62.5930290, gradient norm = 0.0014156 (50 iterations in 2.200s)
# [t-SNE] Iteration 250: error = 62.0750732, gradient norm = 0.0009594 (50 iterations in 2.136s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 62.075073
# [t-SNE] Iteration 300: error = 2.0958877, gradient norm = 0.0048874 (50 iterations in 2.171s)
# [t-SNE] Iteration 350: error = 1.7096696, gradient norm = 0.0027042 (50 iterations in 2.277s)
# [t-SNE] Iteration 400: error = 1.4562172, gradient norm = 0.0017037 (50 iterations in 2.270s)
# [t-SNE] Iteration 450: error = 1.2908561, gradient norm = 0.0011930 (50 iterations in 2.272s)
# [t-SNE] Iteration 500: error = 1.1805546, gradient norm = 0.0008834 (50 iterations in 2.327s)
# [t-SNE] Iteration 550: error = 1.1029449, gradient norm = 0.0006756 (50 iterations in 2.234s)
# [t-SNE] Iteration 600: error = 1.0456715, gradient norm = 0.0005370 (50 iterations in 2.341s)
# [t-SNE] Iteration 650: error = 1.0019882, gradient norm = 0.0004398 (50 iterations in 2.219s)
# [t-SNE] Iteration 700: error = 0.9675570, gradient norm = 0.0003696 (50 iterations in 2.214s)
# [t-SNE] Iteration 750: error = 0.9396938, gradient norm = 0.0003179 (50 iterations in 2.210s)
# [t-SNE] Iteration 800: error = 0.9166989, gradient norm = 0.0002751 (50 iterations in 2.213s)
# [t-SNE] Iteration 850: error = 0.8975456, gradient norm = 0.0002438 (50 iterations in 2.326s)
# [t-SNE] Iteration 900: error = 0.8812262, gradient norm = 0.0002203 (50 iterations in 2.346s)
# [t-SNE] Iteration 950: error = 0.8671509, gradient norm = 0.0001996 (50 iterations in 2.215s)
# [t-SNE] Iteration 1000: error = 0.8551055, gradient norm = 0.0001786 (50 iterations in 2.211s)
# [t-SNE] Error after 1000 iterations: 0.855105

# %%
plot_pca_tsne_nn(X_pca_ec, X_tsne_ec, X_tsne_NN_ec, [x.replace('_',' ') for x in Y], filename='../../datasets/figures/paper_figures/org_visualization.pdf', legend_size=12, label_dic=False, color_idx=2, loc=[(1,2),(1,2),(1,2)])
