# %%
import sys
sys.path.append('../')
import matplotlib.pyplot as plt
# %pylab inline
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from utility.file_utility import FileUtility

# %%
from utility.visualization_utility import create_mat_plot

# %% [markdown]
# # Bodysite

# %%
[label_set, conf, best_score_, best_estimator_,cv_results_, best_params_]=FileUtility.load_obj('../../../git_repos/datasets/results/body-sites/sample-size/6-mers_rate_5000_labels_labels_phen.txt_RF.pickle')
create_mat_plot(conf, ['saliva (o)', 'mid-vagina (u)','a-nares (n)', 'stool (g)', 'p-fornix (u)'], '', 'body-site_confusion', 'Predicted labels' ,'Actual labels', cmap='Purples', filetype='pdf',font_s=15)

# %% [markdown]
# # Organism

# %%
[label_set, conf, best_score_, best_estimator_,cv_results_, best_params_]=FileUtility.load_obj('/mounts/data/proj/asgari/dissertation/git_repos/MicroPheno/results/classification_results/env/6_org_RF.pickle')

# %%
label_set=[x.replace('_',' ') for x in label_set]

# %%
create_mat_plot(conf, label_set, '', '/mounts/data/proj/asgari/dissertation/git_repos/MicroPheno/results/paper_figures/org_env_confusion', 'Predicted labels' ,'Actual labels', cmap='Purples', filetype='pdf')

# %% [markdown]
# # Ecological

# %%
[label_set, conf, best_score_, best_estimator_,cv_results_, best_params_,a]=FileUtility.load_obj('../../datasets/results/eco_10000/classifiers/svm_6_restrictedmers_linear.pickle')

# %%
label_set=[x.replace('_',' ') for x in label_set]
create_mat_plot(conf, label_set, '', '../../datasets/figures/paper_figures/eco_env_confusion', 'Predicted labels' ,'Actual labels', cmap='Purples', filetype='pdf', rx=80, ry=0, font_s=8)

# %%
[label_set, conf, best_score_, best_estimator_,cv_results_, best_params_]=FileUtility.load_obj('../../datasets/results/org/classifier/svm_6_mer_org_linear.pickle')

# %%
label_set=[x.replace('_',' ') for x in label_set]
create_mat_plot(conf, label_set, '', '../../datasets/figures/paper_figures/org_env_confusion', 'Predicted labels' ,'Actual labels', cmap='Purples', filetype='pdf', rx=80, ry=0, font_s=8)

# %%
best_score_
# Out:
# 0.75622695823955222

# %%
'../../datasets/results/eco_10000/classifiers/nn_layers_mlp'
